# %%
from scipy import misc
from matplotlib import pyplot as plt
import numpy as np
from skimage import color
from skimage import io

y,x=[],[]

# %%
img = io.imread('Test3.jpg')
imgGray = color.rgb2gray(img)

print(imgGray)
plt.gray()
plt.axis('off')
plt.imshow(imgGray)
# Out:
# [[0.09777137 0.0938498  0.0938498  ... 0.06666667 0.06666667 0.06666667]
#  [0.08992824 0.08992824 0.08992824 ... 0.06666667 0.06666667 0.06666667]
#  [0.0820851  0.0820851  0.08600667 ... 0.06666667 0.06666667 0.06666667]
#  ...
#  [0.08178745 0.08963059 0.09355216 ... 0.05490196 0.05744745 0.05885412]
#  [0.08178745 0.08963059 0.09747373 ... 0.0529298  0.05661412 0.06113176]
#  [0.07786588 0.08570902 0.09747373 ... 0.0529298  0.05775294 0.06227059]]

# %%
def kernel(img,z,s):
    for i in range(-2.,2):
        for k in range(-2,2):

# %%
f#or z in range(2,len(imgGray)-2):
    for s in range(2,len(imgGray[z])-2):
        v=0
        for yk in range(-2,2):
            for xk in range(-2,2):
                if imgGray[z+yk,s+xk] == int(0):
                    v+=1
        if v>=4:
            x.append(0)
        else:
            x.append(imgGray[z,s])
    y.append(x)
    plt.imshow(y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/friedrichjahns/BScPhysik/Semester 7/Bildgebende Verfahren/Übung/Boxkenrel/maskcreator.ipynb Cell 3' in <cell line: 1>()
#      <a href='vscode-notebook-cell:/home/friedrichjahns/BScPhysik/Semester%207/Bildgebende%20Verfahren/%C3%9Cbung/Boxkenrel/maskcreator.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>         x.append(imgGray[z,s])
#      <a href='vscode-notebook-cell:/home/friedrichjahns/BScPhysik/Semester%207/Bildgebende%20Verfahren/%C3%9Cbung/Boxkenrel/maskcreator.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> y.append(x)
# ---> <a href='vscode-notebook-cell:/home/friedrichjahns/BScPhysik/Semester%207/Bildgebende%20Verfahren/%C3%9Cbung/Boxkenrel/maskcreator.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> plt.imshow(y)
#
# ...

# %%
x = [[1]]
print(x[0][0])
# Out:
# 1
